# %%
import pandas as pd
import numpy as np

# %%
# Assuming ovariantotal.csv is in the same directory
cancer = pd.read_csv("ovariantotal.csv")
print(cancer.head())
print(cancer.shape)
# Out:
#      AFP     AG  Age   ALB  ALP  ALT  AST  BASO#  BASO%   BUN  ...   PCT  \
# 0   3.58  19.36   47  45.4   56   11   24   0.01   0.30  5.35  ...  0.09
# 1  34.24  23.98   61  39.9   95    9   13   0.02   0.30  3.21  ...  0.30
# 2   1.50  18.40   39  45.4   77    9   18   0.03   0.60  3.80  ...  0.13
# 3   2.75  16.60   45  39.2   26   16   17   0.05   0.74  5.27  ...  0.25
# 4   2.36  19.97   45  35.0   47   21   27   0.01   0.10  4.89  ...  0.28
#
#     PDW  PHOS  PLT   RBC   RDW  TBIL    TP     UA  TYPE
# 0  13.4  1.46   74  2.64  13.7   5.5  73.9  396.4     0
# 1  11.2  1.09  304  4.89  12.7   6.8  72.0  119.2     0
# 2  15.2  0.97  112  4.62  12.0  14.8  77.9  209.2     0
# 3  17.4  1.25  339  4.01  14.6  10.9  66.1  215.6     0
# 4  11.9  0.94  272  4.40  13.4   5.3  66.5  206.0     0
#
# [5 rows x 50 columns]
# (349, 50)

# %%
X = cancer.drop('TYPE', axis=1)
y = cancer['TYPE']

from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
print(X_scale)
# Out:
# [[2.45578349e-03 4.85071876e-01 4.70588235e-01 ... 8.37988827e-02
#   7.60667904e-01 5.60447761e-01]
#  [2.78074070e-02 6.55363067e-01 6.76470588e-01 ... 1.20111732e-01
#   7.25417440e-01 4.32835821e-02]
#  [7.35908185e-04 4.49686694e-01 3.52941176e-01 ... 3.43575419e-01
#   8.34879406e-01 2.11194030e-01]
#  ...
#  [1.83563615e-03 4.80280133e-01 6.47058824e-01 ... 3.15642458e-01
#   6.58627087e-01 2.11753731e-01]
#  [1.01704165e-03 7.74788058e-01 2.20588235e-01 ... 2.45810056e-01
#   7.99628942e-01 3.53917910e-01]
#  [8.26863129e-04 2.50645042e-01 3.52941176e-01 ... 1.62011173e-01
#   6.62337662e-01 1.65858209e-01]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scale, y, test_size=0.20, random_state=0)

# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(32, activation='relu', input_dim=49))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# c:\Users\vinay\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(X_train, y_train, batch_size=32, epochs=15)
# Out:
# Epoch 1/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5591 - loss: 0.6874
# Epoch 2/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6810 - loss: 0.6570
# Epoch 3/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7133 - loss: 0.6409
# Epoch 4/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7276 - loss: 0.6207
# Epoch 5/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7348 - loss: 0.6023
# Epoch 6/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7455 - loss: 0.5876
# Epoch 7/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7527 - loss: 0.5668
# Epoch 8/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7527 - loss: 0.5506
# Epoch 9/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7706 - loss: 0.5336
# Epoch 10/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7706 - loss: 0.5156
# Epoch 11/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7849 - loss: 0.5023
# Epoch 12/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7885 - loss: 0.4851
# Epoch 13/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7993 - loss: 0.4711
# Epoch 14/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7993 - loss: 0.4602
# Epoch 15/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8029 - loss: 0.4503

# %%
y_pred = model.predict(X_test)
y_pred = np.where(y_pred > 0.5, 1, 0)
y_pred = y_pred.astype(int)

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nAccuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# Confusion Matrix:
# [[31 10]
#  [ 2 27]]
#
# Accuracy Score: 0.8285714285714286
